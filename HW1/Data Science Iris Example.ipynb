# %% [markdown]
# # Step 1
# ### Using Pandas load Iris Data Set as dataframe from UCI Machine Learning Repository.
# **[Pandas](https://pandas.pydata.org/)**
# **[Iris Data Set](https://archive.ics.uci.edu/ml/datasets/iris)**

# %%
import pandas as pd 

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
                 header=None,
                 names=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'class'])

# %% [markdown]
# # Step 2
# ### Get 10 data as sample randomly and show it.
# **There is a image of the Iris**
# ![Iris](https://ithelp.ithome.com.tw/upload/images/20181017/20112303I4CualrU5X.png)

# %%
df.sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 143                6.8               3.2                5.9               2.3
# 66                 5.6               3.0                4.5               1.5
# 98                 5.1               2.5                3.0               1.1
# 82                 5.8               2.7                3.9               1.2
# 96                 5.7               2.9                4.2               1.3
# 125                7.2               3.2                6.0               1.8
# 30                 4.8               3.1                1.6               0.2
# 120                6.9               3.2                5.7               2.3
# 17                 5.1               3.5                1.4               0.3
# 113                5.7               2.5                5.0               2.0
#
#                class
# 143   Iris-virginica
# 66   Iris-versicolor
# 98   Iris-versicolor
# 82   Iris-versicolor
# ...

# %% [markdown]
# # Step 3
# ### Only show Iris-setosa data

# %%
df[df['class'] == 'Iris-setosa'].sample(10)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 15                5.7               4.4                1.5               0.4
# 16                5.4               3.9                1.3               0.4
# 24                4.8               3.4                1.9               0.2
# 32                5.2               4.1                1.5               0.1
# 43                5.0               3.5                1.6               0.6
# 1                 4.9               3.0                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 17                5.1               3.5                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 9                 4.9               3.1                1.5               0.1
#
#           class
# 15  Iris-setosa
# 16  Iris-setosa
# 24  Iris-setosa
# 32  Iris-setosa
# 43  Iris-setosa
# 1   Iris-setosa
# ...

# %% [markdown]
# # Step 4
# ### Only show sepal length (cm) > 5 data

# %%
df[df['sepal length (cm)'] > 5].sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 132                6.4               2.8                5.6               2.2
# 117                7.7               3.8                6.7               2.2
# 92                 5.8               2.6                4.0               1.2
# 78                 6.0               2.9                4.5               1.5
# 100                6.3               3.3                6.0               2.5
# 62                 6.0               2.2                4.0               1.0
# 32                 5.2               4.1                1.5               0.1
# 118                7.7               2.6                6.9               2.3
# 105                7.6               3.0                6.6               2.1
# 76                 6.8               2.8                4.8               1.4
#
#                class
# 132   Iris-virginica
# 117   Iris-virginica
# 92   Iris-versicolor
# 78   Iris-versicolor
# ...

# %% [markdown]
# # Step 5
# ### Sort data by sepal length (cm)

# %%
df.sort_values(by=['sepal length (cm)']).head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 13                4.3               3.0                1.1               0.1
# 42                4.4               3.2                1.3               0.2
# 38                4.4               3.0                1.3               0.2
# 8                 4.4               2.9                1.4               0.2
# 41                4.5               2.3                1.3               0.3
#
#           class
# 13  Iris-setosa
# 42  Iris-setosa
# 38  Iris-setosa
# 8   Iris-setosa
# 41  Iris-setosa

# %% [markdown]
# # Step 6
# ### Show the statistical data

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# # Step 7
# ### Using matplotlib show the 2D image of data.
# [Matplotlib](https://matplotlib.org/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

colorDict = {
    'Iris-virginica': 0,
    'Iris-versicolor': 1,
    'Iris-setosa': 2
}

plt.xlabel('Sepal length (cm)')
plt.ylabel('Sepal width (cm)')
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c = [colorDict[c] for c in df['class']])

# %% [markdown]
# ### Show the distrubution of three type Iris data.

# %%
plt.pie(
    [len(df[df['class'] == 'Iris-virginica']), len(df[df['class'] == 'Iris-versicolor']), len(df[df['class'] == 'Iris-setosa'])],
    explode=[0.05, 0, 0],
    labels = ['Iris-virginica', 'Iris-versicolor', 'Iris-setosa'],
    autopct= "%3.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x28db7ace880>,
# ...
#  [Text(0.5749999689181257, 0.9959292322972324, 'Iris-virginica'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Iris-versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'Iris-setosa')],
#  [Text(0.324999982431984, 0.5629165226027835, '33.3%'),
#   Text(-0.5999999999999974, -5.6176054134900006e-08, '33.3%'),
#   Text(0.30000008108314646, -0.5196151954572783, '33.3%')])

# %% [markdown]
# # Step 8
# ### Using PCA reduce dimension of data from 4 to 2 by scikit-learn and show 3D imgage.
# [scikit-learn](https://scikit-learn.org/stable/)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

reduced = PCA(n_components=3).fit_transform(df.iloc[:, 0:4])

fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)

ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.set_ylabel("2nd eigenvector")
ax.set_zlabel("3rd eigenvector")

ax.scatter(reduced[:, 0], reduced[:, 1], reduced[:, 2], c = [colorDict[c] for c in df['class']])

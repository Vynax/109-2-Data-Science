# %% [markdown]
# ## Principles and Applications of Data Science
# ## Spring 2021
# ## Homework 1
#
# ### Name: 吳承岳
# ### Student ID Number: 109598085

# %% [markdown]
# # Step 1
# ### Use Pandas to load Abalone Data Set as the  dataframe from UCI Machine Learning Repository.
# **[Pandas](https://pandas.pydata.org/)**
# **[Abalone Data Set](https://archive.ics.uci.edu/ml/datasets/Abalone)**

# %%
import pandas as pd 
# 'abalone.data'
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data',
                 header=None,
                 names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'])

# %% [markdown]
# # Step 2
# ### Get 20 data items as sample randomly and show them.

# %%
df.sample(20)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3902   I   0.160     0.120   0.020        0.0180          0.0075
# 3132   F   0.685     0.530   0.170        1.5105          0.7385
# 4137   M   0.630     0.505   0.155        1.1050          0.4920
# 3361   M   0.410     0.315   0.095        0.3060          0.1210
# 3805   M   0.425     0.305   0.110        0.3590          0.1730
# 215    M   0.550     0.405   0.140        0.8025          0.2440
# 3560   M   0.570     0.470   0.155        1.1860          0.6355
# 2459   F   0.585     0.470   0.170        1.0990          0.3975
# 2285   I   0.420     0.330   0.100        0.3520          0.1635
# 391    M   0.475     0.375   0.125        0.5930          0.2770
# 3076   F   0.680     0.560   0.195        1.6640          0.5800
# 402    F   0.435     0.325   0.110        0.4335          0.1780
# 3758   I   0.525     0.400   0.140        0.6055          0.2605
# 3169   M   0.560     0.450   0.155        0.9125          0.3595
# 3109   I   0.380     0.290   0.085        0.2285          0.0880
# 2883   I   0.500     0.370   0.120        0.5445          0.2490
# 667    F   0.485     0.380   0.150        0.6050          0.2155
# 3603   I   0.420     0.325   0.110        0.3250          0.1245
# 808    F   0.440     0.340   0.130        0.4195          0.1530
# 2345   F   0.710     0.565   0.195        1.7265          0.6380
#
#       Viscera weight  Shell weight  Rings
# 3902          0.0045        0.0050      4
# 3132          0.3525        0.3725     10
# 4137          0.2260        0.3250     11
# 3361          0.0735        0.0900      9
# 3805          0.0875        0.0975      9
# 215           0.1635        0.2550     10
# 3560          0.2315        0.2770     10
# 2459          0.2325        0.3580     20
# 2285          0.0890        0.1000      9
# 391           0.1150        0.1800     10
# 3076          0.3855        0.5450     11
# 402           0.0985        0.1550      7
# 3758          0.1080        0.2100      9
# 3169          0.2710        0.3500     10
# 3109          0.0465        0.0750      7
# 2883          0.1065        0.1520      8
# 667           0.1400        0.1800     15
# 3603          0.0755        0.1025      7
# 808           0.1155        0.1300     10
# 2345          0.3365        0.5650     17

# %% [markdown]
# # Step 3
# ### Show 20 data items of Abalone-infant as sample randomly.

# %%
df[df['Sex'] == 'I'].sample(20)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1685   I   0.620     0.450   0.135        0.9240          0.3580
# 1592   I   0.525     0.390   0.120        0.6640          0.3115
# 2640   I   0.465     0.355   0.105        0.4420          0.2085
# 2980   I   0.500     0.370   0.115        0.5745          0.3060
# 576    I   0.560     0.425   0.140        0.9175          0.4005
# 1558   I   0.425     0.315   0.080        0.3030          0.1310
# 1452   I   0.470     0.345   0.140        0.4615          0.2290
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 69     I   0.310     0.235   0.070        0.1510          0.0630
# 2397   I   0.635     0.505   0.190        1.3315          0.5805
# 839    I   0.485     0.355   0.105        0.4980          0.2175
# 3973   I   0.415     0.330   0.100        0.3905          0.1925
# 1610   I   0.545     0.420   0.125        0.7170          0.3580
# 2507   I   0.415     0.325   0.100        0.4665          0.2285
# 1053   I   0.185     0.130   0.045        0.0290          0.0120
# 1329   I   0.570     0.450   0.135        0.7940          0.3815
# 3915   I   0.560     0.445   0.165        1.0285          0.4535
# 605    I   0.425     0.345   0.125        0.4250          0.1600
# 1824   I   0.185     0.135   0.040        0.0270          0.0105
# 943    I   0.465     0.345   0.110        0.4415          0.1755
#
#       Viscera weight  Shell weight  Rings
# 1685          0.2265        0.2965     10
# 1592          0.1470        0.1780      9
# 2640          0.0975        0.1185      7
# 2980          0.1120        0.1410      7
# 576           0.1975        0.2600     10
# 1558          0.0585        0.0950      7
# 1452          0.1105        0.1160      9
# 719           0.0040        0.0050      2
# 69            0.0405        0.0450      6
# 2397          0.2520        0.4350     17
# 839           0.0960        0.1525      9
# 3973          0.0755        0.1025      7
# 1610          0.1120        0.2200      8
# 2507          0.1065        0.1140      7
# 1053          0.0075        0.0095      4
# 1329          0.1415        0.2450      8
# 3915          0.2530        0.2750     11
# 605           0.0795        0.1540     13
# 1824          0.0055        0.0090      5
# 943           0.0905        0.1200      7

# %% [markdown]
# # Step 4
# ### Sort the data by Whole weight (grams) and present the top 20 data items.

# %%
df.sort_values(by=['Whole weight']).head(20)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 1429   I   0.140     0.105   0.035        0.0140          0.0055
# 3899   I   0.140     0.105   0.035        0.0145          0.0050
# 2169   I   0.165     0.115   0.015        0.0145          0.0055
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 526    M   0.155     0.110   0.040        0.0155          0.0065
# 696    I   0.155     0.105   0.050        0.0175          0.0050
# 720    I   0.160     0.110   0.025        0.0180          0.0065
# 3902   I   0.160     0.120   0.020        0.0180          0.0075
# 694    I   0.165     0.110   0.020        0.0190          0.0065
# 1987   I   0.160     0.110   0.025        0.0195          0.0075
# 3472   I   0.165     0.120   0.050        0.0210          0.0075
# 239    I   0.160     0.120   0.035        0.0210          0.0075
# 306    I   0.165     0.120   0.030        0.0215          0.0070
# 2371   M   0.180     0.125   0.050        0.0230          0.0085
# 2343   I   0.170     0.125   0.055        0.0235          0.0090
# 465    I   0.175     0.125   0.050        0.0235          0.0080
#
#       Viscera weight  Shell weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 2114          0.0065        0.0035      4
# 237           0.0030        0.0040      3
# 1429          0.0025        0.0040      3
# 3899          0.0035        0.0050      4
# 2169          0.0030        0.0050      4
# 719           0.0040        0.0050      2
# 526           0.0030        0.0050      3
# 696           0.0035        0.0050      4
# 720           0.0055        0.0050      3
# 3902          0.0045        0.0050      4
# 694           0.0025        0.0050      4
# 1987          0.0050        0.0060      4
# 3472          0.0045        0.0140      3
# 239           0.0045        0.0050      5
# 306           0.0050        0.0050      3
# 2371          0.0055        0.0100      3
# 2343          0.0055        0.0080      6
# 465           0.0035        0.0080      5

# %% [markdown]
# # Step 5
# ### Show the simple statistical information.

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# # Use matplotlib show 2D images about data.
# [Matplotlib](https://matplotlib.org/)

# %% [markdown]
# # Step 6
# ### Plot the distribution of three types of Abalone using different colors where x-axis is the diameter and y-axis the whole weight

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

colorDict = {
    'I': 0,
    'M': 1,
    'F': 2
}

plt.xlabel('Diameter')
plt.ylabel('Whole weight')
plt.scatter(df['Diameter'], df['Whole weight'], c = [colorDict[c] for c in df['Sex']])

# %% [markdown]
# # Step 7
# ### Show the proportion of three types of Abalone using pie chart.

# %%
plt.pie(
    [len(df[df['Sex'] == 'I']), len(df[df['Sex'] == 'M']), len(df[df['Sex'] == 'F'])],
    explode=[0.05, 0, 0],
    labels = ['Infant', 'Male', 'Female'],
    autopct= "%3.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2407f6681c0>,
#   <matplotlib.patches.Wedge at 0x2407f668940>,
#   <matplotlib.patches.Wedge at 0x2407f6740a0>],
#  [Text(0.6122814608527014, 0.9734533438722587, 'Infant'),
#   Text(-1.0996188950042185, -0.028953164761411885, 'Male'),
#   Text(0.6099659291018239, -0.9153914820091724, 'Female')],
#  [Text(0.346072130047179, 0.5502127595799723, '32.1%'),
#   Text(-0.5997921245477555, -0.01579263532440648, '36.6%'),
#   Text(0.3327086886009948, -0.49930444473227575, '31.3%')])
